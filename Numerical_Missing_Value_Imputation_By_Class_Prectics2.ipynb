# %% [markdown]
# <a href="https://colab.research.google.com/github/Borhanuddin672012/Sample_coding/blob/main/Numerical_Missing_Value_Imputation_By_Class_Prectics2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Numerical Missing Value Imputation By Class**

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
df = "/content/drive/MyDrive/train.csv"

# %%
df2 = pd.read_csv(df)
df2
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
  df2.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df2.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
df2.isnull().sum().unique()
# Out:
# array([   0,  259, 1369,    8,   37,   38,    1,  690,   81, 1453, 1179,
#        1406])

# %%
df2.isnull().sum().sum()
# Out:
# 6965

# %%
df2.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#df2_percentage_count = df2.isnull().sum()/ df.shape[0]*100

# %%
df2_remove_20_percentage  =['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']
df2_drop_clm = df2.drop(columns=df2_remove_20_percentage)

# %%
df2_int_float_type  = df2_drop_clm.select_dtypes(include=['int64','float64'])
df2_int_float_type.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
df2_int_float_type.shape
# Out:
# (1460, 38)

# %%
df2_int_float_type.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
num_var_miss = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
df2_int_float_type[num_var_miss][df2_int_float_type[num_var_miss].isnull().any(axis=1)].head()
# Out:
#     LotFrontage  MasVnrArea  GarageYrBlt
# 7           NaN       240.0       1973.0
# 12          NaN         0.0       1962.0
# 14          NaN       212.0       1960.0
# 16          NaN       180.0       1970.0
# 24          NaN         0.0       1968.0

# %%
df2['LotConfig'].unique()
# Out:
# array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object)

# %%
df2_Inside=df2[df2.loc[:,'LotConfig'] == "Inside"]
df2_Inside.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 5         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 6         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 8         Lvl    AllPub    Inside       Gtl      OldTown     Artery
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df2_Inside.isnull().sum().head()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage    134
# LotArea          0
# dtype: int64

# %%
df2_Corner=df2[df2.loc[:,'LotConfig'] == "Corner"]
df2_Corner.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 14  15          20       RL          NaN    10920   Pave   NaN      IR1
# 15  16          45       RM         51.0     6120   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 3          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 7          Lvl    AllPub    Corner       Gtl       NWAmes       PosN
# 9          Lvl    AllPub    Corner       Gtl      BrkSide     Artery
# 14         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 15         Lvl    AllPub    Corner       Gtl      BrkSide       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df2_CulDSac=df2[df2.loc[:,'LotConfig'] == "CulDSac"]
df2_CulDSac.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 16  17          20       RL          NaN    11241   Pave   NaN      IR1
# 28  29          20       RL         47.0    16321   Pave   NaN      IR1
# 31  32          20       RL          NaN     8544   Pave   NaN      IR1
# 42  43          85       RL          NaN     9180   Pave   NaN      IR1
# 43  44          20       RL          NaN     9200   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 16         Lvl    AllPub   CulDSac       Gtl        NAmes       Norm
# 28         Lvl    AllPub   CulDSac       Gtl        NAmes       Norm
# 31         Lvl    AllPub   CulDSac       Gtl       Sawyer       Norm
# 42         Lvl    AllPub   CulDSac       Gtl      SawyerW       Norm
# 43         Lvl    AllPub   CulDSac       Gtl      CollgCr       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df2_FR3=df2[df2.loc[:,'LotConfig'] == "FR3"]
df2_FR3.head()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 333    334         120       RM         59.0     8198   Pave   NaN      Reg
# 531    532          70       RM         60.0     6155   Pave   NaN      IR1
# 1265  1266         160       FV         35.0     3735   Pave   NaN      Reg
# 1359  1360          20       RL        129.0    16737   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 333          Lvl    AllPub       FR3       Gtl      NridgHt       Norm
# 531          Lvl    AllPub       FR3       Gtl      BrkSide       RRNn
# 1265         Lvl    AllPub       FR3       Gtl      Somerst       Norm
# 1359         Lvl    AllPub       FR3       Gtl      NridgHt       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 333        Norm   TwnhsE     1Story            7            5       2004
# 531       Feedr     1Fam     2Story            6            8       1920
# ...

# %%
 df2[df2.loc[:,'LotConfig'] == "Inside"]["LotFrontage"].head()
# Out:
# 0    65.0
# 2    68.0
# 5    85.0
# 6    75.0
# 8    51.0
# Name: LotFrontage, dtype: float64

# %%
#df[df.loc[:,'LotConfig'] == "Inside"]["LotFrontage"].replace(np.nan,df[df.loc[:,'LotConfig'] == "Inside"]["LotFrontage"].mean())
df2_mean = df2[df2.loc[:,'LotConfig'] == "Inside"]["LotFrontage"].replace(np.nan, df2[df2.loc[:,'LotConfig'] == "Inside"]["LotFrontage"].mean())

# %%
df2_mean.isnull().sum()
# Out:
# 0

# %%
df2['LotConfig'].unique()
# Out:
# array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object)

# %%
df2_FR2 = df2[df2.loc[:,'LotConfig'] == "FR2"]["LotFrontage"].replace(np.nan, df2[df2.loc[:,'LotConfig'] == "FR2"]["LotFrontage"].mean())

# %%
df2_FR2.isnull().sum()
# Out:
# 0

# %%
df2['LotConfig'].unique()
# Out:
# array(['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3'], dtype=object)

# %%
df2_Corner = df2[df2.loc[:,'LotConfig'] == "Corner"]["LotFrontage"].replace(np.nan, df2[df2.loc[:,'LotConfig'] == "Corner"]["LotFrontage"].mean())
df2_Corner.isnull().sum()
# Out:
# 0

# %%
df2_CulDSac = df2[df2.loc[:,'LotConfig'] == "CulDSac"]["LotFrontage"].replace(np.nan, df2[df2.loc[:,'LotConfig'] == "CulDSac"]["LotFrontage"].mean())
df2_CulDSac.isnull().sum()
# Out:
# 0

# %%
df2_FR3 = df2[df2.loc[:,'LotConfig'] == "FR3"]["LotFrontage"].replace(np.nan, df2[df2.loc[:,'LotConfig'] == "FR3"]["LotFrontage"].mean())
df2_FR3.isnull().sum()
# Out:
# 0

# %%
#df2_mean = df2[df2.loc[:,'LotConfig'] == "Inside"]["LotFrontage"].replace(np.nan, df2[df2.loc[:,'LotConfig'] == "Inside"]["LotFrontage"].mean())

# %%
#df_copy = df.copy() 
#for var_class in df['LotConfig'].unique():
 #   df_copy.update(df[df.loc[:,'LotConfig'] == var_class]["LotFrontage"].replace(np.nan,df[df.loc[:,'LotConfig'] == var_class]["LotFrontage"].mean()))

# %%
df_copy = df2.copy()
for var_class in df2['LotConfig'].unique():
  df_copy.update(df2[df2.loc[:,'LotConfig'] == "Inside"]["LotFrontage"].replace(np.nan, df2[df2.loc[:,'LotConfig'] == "Inside"]["LotFrontage"].mean()))

# %%
df_copy.isnull().sum().head()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage    125
# LotArea          0
# dtype: int64

# %%
df_copy = df2.copy()
for var_class in df2['LotConfig'].unique():
  df_copy.update(df2[df2.loc[:,'LotConfig'] == var_class]["LotFrontage"].replace(np.nan, df2[df2.loc[:,'LotConfig'] == var_class]["LotFrontage"].mean()))

# %%
df_copy.isnull().sum().head()
# Out:
# Id             0
# MSSubClass     0
# MSZoning       0
# LotFrontage    0
# LotArea        0
# dtype: int64

# %%
num_var_miss = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
df2_int_float_type[num_var_miss][df2_int_float_type[num_var_miss].isnull().any(axis=1)].head()
# Out:
#     LotFrontage  MasVnrArea  GarageYrBlt
# 7           NaN       240.0       1973.0
# 12          NaN         0.0       1962.0
# 14          NaN       212.0       1960.0
# 16          NaN       180.0       1970.0
# 24          NaN         0.0       1968.0

# %%
df_copy = df2.copy()
num_vars_miss = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
cat_vars = ['LotConfig','MasVnrType','GarageType']
for cat_var, num_var_miss in zip(cat_vars,num_vars_miss):
    for var_class in df2[cat_var].unique():
        df_copy.update(df2[df2.loc[:,cat_var] == var_class][num_var_miss].replace(np.nan,df2[df2.loc[:,cat_var] == var_class][num_var_miss].mean()))

# %%
df_copy[num_vars_miss].isnull().sum()
# Out:
# LotFrontage     0
# MasVnrArea      8
# GarageYrBlt    81
# dtype: int64

# %%
df_copy[df_copy[['MasVnrType']].isnull().any(axis=1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 234    235          60       RL    67.715686     7851   Pave   NaN      Reg
# 529    530          20       RL    59.911111    32668   Pave   NaN      IR1
# 650    651          60       FV    65.000000     8125   Pave   NaN      Reg
# 936    937          20       RL    67.000000    10083   Pave   NaN      Reg
# 973    974          20       FV    95.000000    11639   Pave   NaN      Reg
# 977    978         120       FV    35.000000     4274   Pave  Pave      IR1
# 1243  1244          20       RL   107.000000    13891   Pave   NaN      Reg
# 1278  1279          60       RL    75.000000     9473   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 234          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 529          Lvl    AllPub   CulDSac       Gtl      Crawfor       Norm
# ...

# %%
df_copy[df_copy[['GarageType']].isnull().any(axis=1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL    65.000000     6040   Pave   NaN      Reg
# 48      49         190       RM    33.000000     4456   Pave   NaN      Reg
# 78      79          90       RL    72.000000    10778   Pave   NaN      Reg
# 88      89          50  C (all)   105.000000     8470   Pave   NaN      IR1
# 89      90          20       RL    60.000000     8070   Pave   NaN      Reg
# 99     100          20       RL    77.000000     9320   Pave   NaN      IR1
# 108    109          50       RM    85.000000     8500   Pave   NaN      Reg
# 125    126         190       RM    60.000000     6780   Pave   NaN      Reg
# 127    128          45       RM    55.000000     4388   Pave   NaN      IR1
# 140    141          20       RL    70.000000    10500   Pave   NaN      Reg
# 148    149          20       RL    63.000000     7500   Pave   NaN      Reg
# ...

# %%
df_copy = df2.copy()
num_vars_miss = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
cat_vars = ['LotConfig','Exterior2nd','KitchenQual']
for cat_var, num_var_miss in zip(cat_vars,num_vars_miss):
    for var_class in df2[cat_var].unique():
        df_copy.update(df2[df2.loc[:,cat_var] == var_class][num_var_miss].replace(np.nan,df2[df2.loc[:,cat_var] == var_class][num_var_miss].mean()))

# %%
df_copy[num_vars_miss].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %% [markdown]
# # **Data Distribution**

# %%
plt.figure(figsize=(10,10))
sns.set()
for i, var in enumerate(num_vars_miss):
    plt.subplot(2,2,i+1)
    sns.distplot(df2[var], bins=20, kde_kws={'linewidth':8, 'color':'red'}, label="Original",)
    sns.distplot(df_copy[var], bins=20, kde_kws={'linewidth':5, 'color':'green'},label="Mean",)
    plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# **Median**

# %%
df_copy_median = df2.copy()
num_vars_miss = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
cat_vars = ['LotConfig','Exterior2nd','KitchenQual']
for cat_var, num_var_miss in zip(cat_vars,num_vars_miss):
    for var_class in df2[cat_var].unique():
        df_copy_median.update(df2[df2.loc[:,cat_var] == var_class][num_var_miss].replace(np.nan,df2[df2.loc[:,cat_var] == var_class][num_var_miss].median()))

# %%
df_copy_median[num_vars_miss].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.set()
for i, var in enumerate(num_vars_miss):
    plt.subplot(2,2,i+1)
    sns.distplot(df2[var], bins=20, kde_kws={'linewidth':8, 'color':'red'}, label="Original")
    sns.distplot(df_copy[var], bins=20, kde_kws={'linewidth':5, 'color':'green'},label="Mean")
    sns.distplot(df_copy_median[var], bins=20, kde_kws={'linewidth':3, 'color':'k'},label="Median")
    plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for i, var in enumerate(num_vars_miss):
    plt.figure(figsize=(10,10))
    plt.subplot(3,1,1)
    sns.boxplot(df2[var])
    plt.subplot(3,1,2)
    sns.boxplot(df_copy[var])
    plt.subplot(3,1,3)
    sns.boxplot(df_copy_median[var])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...
