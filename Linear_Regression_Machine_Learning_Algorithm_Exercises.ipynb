# %% [markdown]
# <a href="https://colab.research.google.com/github/Borhanuddin672012/Sample_coding/blob/main/Linear_Regression_Machine_Learning_Algorithm_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Linear Regression Machine Learning Algorithm**
# In this ML course tutorial, we are going to learn the “Linear Regression Machine Learning Algorithm in detail. we covered Simple Linear regression and Multiple Linear regression supervised regression learning algorithm by practical and theoretical intuition.
#
# [INDIAN AI PRODUCTION](https://indianaiproduction.com/linear-regression)
#
# [You tube ](https://www.youtube.com/watch?v=AEZHFA3qgB8&list=PLfP3JxW-T70HLRjrFP88sWlIDUlKahx8A&index=89)

# %% [markdown]
# # **Load Libraries**

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Bengaluru_House_Data.csv")

# %%
df2 = pd.get_dummies(df)

# %%
df2.head()
# Out:
#    bath  balcony   price  ...  total_sqft_997  total_sqft_998  total_sqft_999
# 0   2.0      1.0   39.07  ...               0               0               0
# 1   5.0      3.0  120.00  ...               0               0               0
# 2   2.0      3.0   62.00  ...               0               0               0
# 3   3.0      1.0   95.00  ...               0               0               0
# 4   2.0      1.0   51.00  ...               0               0               0
#
# [5 rows x 6229 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Columns: 6229 entries, bath to total_sqft_999
# dtypes: float64(3), uint8(6226)
# memory usage: 79.4 MB

# %%
df2.describe()
# Out:
#                bath       balcony  ...  total_sqft_998  total_sqft_999
# count  13247.000000  12711.000000  ...    13320.000000    13320.000000
# mean       2.692610      1.584376  ...        0.000075        0.000225
# std        1.341458      0.817263  ...        0.008665        0.015006
# min        1.000000      0.000000  ...        0.000000        0.000000
# 25%        2.000000      1.000000  ...        0.000000        0.000000
# 50%        2.000000      2.000000  ...        0.000000        0.000000
# 75%        3.000000      2.000000  ...        0.000000        0.000000
# max       40.000000      3.000000  ...        1.000000        1.000000
#
# [8 rows x 6229 columns]

# %%
df2.isnull().sum()
# Out:
# bath                         73
# balcony                     609
# price                         0
# area_type_Built-up  Area      0
# area_type_Carpet  Area        0
#                            ...
# total_sqft_995                0
# total_sqft_996                0
# total_sqft_997                0
# total_sqft_998                0
# total_sqft_999                0
# Length: 6229, dtype: int64

# %%
sns.heatmap(df2.isnull())

# %%
remove_null_values = df2.isnull().sum()/df.shape[0]*100
remove_null_values
# Out:
# bath                        0.548048
# balcony                     4.572072
# price                       0.000000
# area_type_Built-up  Area    0.000000
# area_type_Carpet  Area      0.000000
#                               ...
# total_sqft_995              0.000000
# total_sqft_996              0.000000
# total_sqft_997              0.000000
# total_sqft_998              0.000000
# total_sqft_999              0.000000
# Length: 6229, dtype: float64

# %%
drop_colums = remove_null_values[remove_null_values>17]
drop_colums
# Out:
# Series([], dtype: float64)

# %%
df2_drop_clm = df2.drop(columns=drop_colums)

# %%
df2_drop_clm.shape
# Out:
# (13320, 6229)

# %%
df2_drop_clm
# Out:
#        bath  balcony   price  ...  total_sqft_997  total_sqft_998  total_sqft_999
# 0       2.0      1.0   39.07  ...               0               0               0
# 1       5.0      3.0  120.00  ...               0               0               0
# 2       2.0      3.0   62.00  ...               0               0               0
# 3       3.0      1.0   95.00  ...               0               0               0
# 4       2.0      1.0   51.00  ...               0               0               0
# ...     ...      ...     ...  ...             ...             ...             ...
# 13315   4.0      0.0  231.00  ...               0               0               0
# 13316   5.0      NaN  400.00  ...               0               0               0
# 13317   2.0      1.0   60.00  ...               0               0               0
# 13318   4.0      1.0  488.00  ...               0               0               0
# ...

# %% [markdown]
# Splite Data

# %%
from sklearn.model_selection import  train_test_split
X_train,X_test, y_test,y_test = train_test_split(X,y, test_size = 0.2, random_state =51)
print('Shape of X_train = ', X_train.shape)
print('Shape of y_train = ', y_train.shape)
print('Shape of X_test = ', X_test.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of X_train =  (10656, 6228)
# Shape of y_train =  (10656,)
# Shape of X_test =  (2664, 6228)
# Shape of y_test =  (2664,)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# **Linear Regression - ML Model Training**

# %%
from sklearn.linear_model import  LinearRegression
LR = LinearRegression()
LR.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-33b5445e8634> in <module>()
#       1 from sklearn.linear_model import  LinearRegression
#       2 LR = LinearRegression()
# ----> 3 LR.fit(X_train, y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
|
